# %% [markdown]
# # LIVE FACE FILTERS

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("image.png")

# %%
def apply_cartoon_effect(img):
    """Apply cartoon effect to image"""
    # Smooth the image
    color = cv2.bilateralFilter(img, 9, 300, 300)
    
    # Convert to grayscale and apply median blur
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.medianBlur(gray, 7)
    
    # Detect and enhance edges
    edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                                 cv2.THRESH_BINARY, 9, 10)
    
    # Convert edges to color
    edges_color = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)
    
    # Combine with color image
    cartoon = cv2.bitwise_and(color, edges_color)
    return cartoon

# Apply cartoon effect to your image
cartoon_image = apply_cartoon_effect(image)
cartoon_rgb = cv2.cvtColor(cartoon_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('🎨 Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cartoon_rgb)
plt.title('🎭 Cartoon Effect')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\D I S\AppData\Local\Temp\ipykernel_16172\1516107987.py:37: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\D I S\AppData\Local\Temp\ipykernel_16172\1516107987.py:37: UserWarning: Glyph 127917 (\N{PERFORMING ARTS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\D I S\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\D I S\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127917 (\N{PERFORMING ARTS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
